# %%
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
import matplotlib.pyplot as plt

# %%
#Importar el dataset
boston = datasets.load_boston()
print(boston.data.shape)
# Out:
# (506, 13)

# %%
#Selección de datos
X = boston.data[:,np.newaxis,5]
y = boston.target
print(X.shape)
# Out:
# (506, 1)

# %%
#Presentación de los datos
plt.scatter(X,y)
plt.show()

# %%
#Selección de train y test set
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
#Se define el algoritmo

#svr = SVR(C = 100.,epsilon = 0.2)
svr = SVR()

# %%
#Entrenamiento del algoritmo
svr.fit(X_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#Predicción
y_predict = svr.predict(X_test)

# %%
plt.scatter(X, y)
plt.scatter(X_test, y_predict)

# %%
print(svr.score(X_train,y_train))
# Out:
# 0.5826086265187871

# %%
#Se define el algoritmo con kernel 'linear'

svrlin = SVR(kernel = 'linear',C = 100.,epsilon = 0.2)

# %%
#Entrenamiento del algoritmo
svrlin.fit(X_train,y_train)
# Out:
# SVR(C=100.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.2,
#   gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#Predicción
y_predict_lin = svrlin.predict(X_test)

# %%
plt.scatter(X, y)
plt.scatter(X_test, y_predict_lin)

# %%
print(svrlin.score(X_train,y_train))
# Out:
# 0.501416129449108
